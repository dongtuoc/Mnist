# %% [markdown]
# # 手写数字识别

# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from matplotlib import pyplot as plt
# %matplotlib inline

#打印等级
tf.logging.set_verbosity(tf.logging.INFO)

# %%
#数据集所在路径
url = "./"

mnist = input_data.read_data_sets(url)

#打印一下数据集
print(mnist.train.images.shape)
print(mnist.train.labels.shape)

print(mnist.validation.images.shape)
print(mnist.validation.labels.shape)

print(mnist.test.images.shape)
print(mnist.test.labels.shape)
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# (55000, 784)
# (55000,)
# (5000, 784)
# (5000,)
# (10000, 784)
# (10000,)

# %%
x = tf.placeholder("float",[None,784])
y = tf.placeholder("int64",[None])
learning_rate = tf.placeholder("float")

# %%
#高斯分布初始化
def initialize(shape,stddev=0.1):
    return tf.truncated_normal(shape,stddev=0.1)

#Xavier初始化
def Xavier(node_in,node_out):
    return np.random.randn(node_in,node_out).astype('float32')/np.sqrt(node_in)

#MSRA 初始化
def MSRA(node_in,node_out):
      return np.random.randn(node_in,node_out).astype('float32') / np.sqrt(node_in/2)

'''
构造神经网络
hidden1为与输入层连接的隐藏层
**kwags为可变参数，可以传入任意数目的隐层
initial_way为初始化方式
'''
def create_network(hidden1,initial_way,**kwags):
    hiddens = [hidden1]
    #高斯
    if initial_way == initialize:
        W = tf.Variable(initial_way([784,hidden1]))
        b = tf.Variable(initial_way([hidden1]))
    else:
        W = tf.Variable(initial_way(784,hidden1))
        b = tf.Variable(initial_way(1,hidden1))
    
    #w未经激活的输出
    logits = tf.matmul(x,W)+b
    #通过Relu函数激活
    output = tf.nn.relu(logits)

    if kwags != '':
        for k in kwags:
            if initial_way == initialize: #高斯
                W = tf.Variable(initial_way([hiddens[-1],kwags[k]]))
                b = tf.Variable(initial_way([kwags[k]]))
            else:
                W = tf.Variable(initial_way(hiddens[-1], kwags[k]))
                b = tf.Variable(initial_way(1, kwags[k]))
    
            logits = tf.matmul(output,W)+b
            output = tf.nn.relu(logits)
    
    if initial_way == initialize:
        W = tf.Variable(initial_way([hiddens[-1], 10]))
        b = tf.Variable(initial_way([10]))
    else:
        W = tf.Variable(initial_way(hiddens[-1], 10))
        b = tf.Variable(initial_way(1, 10))       
    
    logits = tf.matmul(output,W)+b
    
    return logits,W




'''
lambda_flag为正则参数，L1/L2,默认为None
lambda_value为正则系数
initial_way初始化分布,默认高斯分布
'''
def train(batch_size,training_step,lr,hidden1,lambda_flag=None,lambda_value=0.1,initial_way=initialize,**kwags):
    
    logits,W = create_network(hidden1,initial_way,**kwags)
    if lambda_flag == 'l1':#L1正则
        cross_entropy_loss = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits,labels=y)
            + tf.contrib.layers.l1_regularizer(lambda_value)(W))
    if lambda_flag == 'l2':#L2正则
        cross_entropy_loss = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits,labels=y)
            + tf.contrib.layers.l2_regularizer(lambda_value)(W))

    if lambda_flag is None:
        cross_entropy_loss = tf.reduce_mean(
        tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits,labels=y))

    #优化器 最速下降
    optimizer = tf.train.GradientDescentOptimizer(
    learning_rate=learning_rate).minimize(cross_entropy_loss)
    
    pred = tf.nn.softmax(logits)
    correct_pred = tf.equal(tf.arg_max(pred,1),y)
    accuracy = tf.reduce_mean(tf.cast(correct_pred,tf.float32))
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        train_data = {
            x:mnist.train.images,
            y:mnist.train.labels,
        }
        
        validate_data = {
            x:mnist.validation.images,
            y:mnist.validation.labels,
        }
        test_data = {
            x:mnist.test.images,
            y:mnist.test.labels,
        }

        #训练步数
        for i in range(training_step):
            xs,ys = mnist.train.next_batch(batch_size)
            _,loss = sess.run(
                [optimizer,cross_entropy_loss],
                feed_dict={
                    x:xs,y:ys,learning_rate:lr
                }
            )

            if (i) > 0 and (i) % 100 == 0:
                validata_accuracy = sess.run(accuracy,feed_dict=validate_data)
                print(
                "after %d training steps, the loss is %g, the validation accuracy is %g" 
                % (i,loss,validata_accuracy)
                )

        print("the traning is finish!")

        acc_train=sess.run(accuracy,feed_dict=train_data)
        acc_test = sess.run(accuracy,feed_dict=test_data)
        print("the train accuracy is :",acc_train)
        print("the test accuracy is :",acc_test)

# %% [markdown]
# ## 初始状态

# %%
train(batch_size=32,training_step=1000,lr=0.3,hidden1=100)
# Out:
# after 100 training steps, the loss is 0.71379, the validation accuracy is 0.8512
# after 200 training steps, the loss is 0.197124, the validation accuracy is 0.9144
# after 300 training steps, the loss is 0.346137, the validation accuracy is 0.914
# after 400 training steps, the loss is 0.237436, the validation accuracy is 0.9316
# after 500 training steps, the loss is 0.368397, the validation accuracy is 0.938
# after 600 training steps, the loss is 0.23627, the validation accuracy is 0.9378
# after 700 training steps, the loss is 0.396076, the validation accuracy is 0.9454
# after 800 training steps, the loss is 0.425638, the validation accuracy is 0.947
# after 900 training steps, the loss is 0.0755001, the validation accuracy is 0.9576
# the traning is finish!
# the train accuracy is : 0.9520909
# the test accuracy is : 0.9499

# %% [markdown]
# 可以看到在未进行参数调优之前，准确率只有94%左右

# %% [markdown]
# ## 下面增加训练次数至20000 ，并降低学习率至0.1

# %%
train(batch_size=32,training_step=20000,lr=0.1,hidden1=100)
# Out:
# after 100 training steps, the loss is 0.519801, the validation accuracy is 0.8366
# after 200 training steps, the loss is 0.570863, the validation accuracy is 0.8868
# after 300 training steps, the loss is 0.479428, the validation accuracy is 0.893
# after 400 training steps, the loss is 0.28, the validation accuracy is 0.9134
# after 500 training steps, the loss is 0.378267, the validation accuracy is 0.9072
# after 600 training steps, the loss is 0.449428, the validation accuracy is 0.9188
# after 700 training steps, the loss is 0.234085, the validation accuracy is 0.919
# after 800 training steps, the loss is 0.0979101, the validation accuracy is 0.926
# after 900 training steps, the loss is 0.484325, the validation accuracy is 0.9328
# after 1000 training steps, the loss is 0.0974513, the validation accuracy is 0.9314
# after 1100 training steps, the loss is 0.15352, the validation accuracy is 0.9366
# after 1200 training steps, the loss is 0.382811, the validation accuracy is 0.9344
# after 1300 training steps, the loss is 0.165741, the validation accuracy is 0.9426
# after 1400 training steps, the loss is 0.0549172, the validation accuracy is 0.9464
# after 1500 training steps, the loss is 0.23943, the validation accuracy is 0.9412
# after 1600 training steps, the loss is 0.321284, the validation accuracy is 0.9472
# after 1700 training steps, the loss is 0.0812499, the validation accuracy is 0.9428
# after 1800 training steps, the loss is 0.219251, the validation accuracy is 0.949
# after 1900 training steps, the loss is 0.393729, the validation accuracy is 0.953
# after 2000 training steps, the loss is 0.246912, the validation accuracy is 0.946
# after 2100 training steps, the loss is 0.408653, the validation accuracy is 0.9524
# after 2200 training steps, the loss is 0.248375, the validation accuracy is 0.9552
# after 2300 training steps, the loss is 0.181653, the validation accuracy is 0.957
# after 2400 training steps, the loss is 0.249685, the validation accuracy is 0.9566
# after 2500 training steps, the loss is 0.124692, the validation accuracy is 0.9562
# after 2600 training steps, the loss is 0.182147, the validation accuracy is 0.9566
# after 2700 training steps, the loss is 0.176356, the validation accuracy is 0.9548
# after 2800 training steps, the loss is 0.412988, the validation accuracy is 0.9576
# after 2900 training steps, the loss is 0.169349, the validation accuracy is 0.9596
# after 3000 training steps, the loss is 0.174442, the validation accuracy is 0.9582
# after 3100 training steps, the loss is 0.162805, the validation accuracy is 0.96
# after 3200 training steps, the loss is 0.181712, the validation accuracy is 0.961
# after 3300 training steps, the loss is 0.0779547, the validation accuracy is 0.9596
# after 3400 training steps, the loss is 0.097213, the validation accuracy is 0.9618
# after 3500 training steps, the loss is 0.107273, the validation accuracy is 0.9634
# after 3600 training steps, the loss is 0.069218, the validation accuracy is 0.958
# after 3700 training steps, the loss is 0.162135, the validation accuracy is 0.9632
# after 3800 training steps, the loss is 0.155071, the validation accuracy is 0.9634
# after 3900 training steps, the loss is 0.0803416, the validation accuracy is 0.9632
# after 4000 training steps, the loss is 0.448907, the validation accuracy is 0.9628
# after 4100 training steps, the loss is 0.0261156, the validation accuracy is 0.9636
# after 4200 training steps, the loss is 0.107663, the validation accuracy is 0.9648
# after 4300 training steps, the loss is 0.127283, the validation accuracy is 0.9616
# after 4400 training steps, the loss is 0.527501, the validation accuracy is 0.9642
# after 4500 training steps, the loss is 0.312028, the validation accuracy is 0.9648
# after 4600 training steps, the loss is 0.164744, the validation accuracy is 0.9668
# after 4700 training steps, the loss is 0.0847775, the validation accuracy is 0.9656
# after 4800 training steps, the loss is 0.232565, the validation accuracy is 0.9636
# after 4900 training steps, the loss is 0.202614, the validation accuracy is 0.969
# after 5000 training steps, the loss is 0.0554196, the validation accuracy is 0.9682
# after 5100 training steps, the loss is 0.107634, the validation accuracy is 0.964
# after 5200 training steps, the loss is 0.0646026, the validation accuracy is 0.9654
# after 5300 training steps, the loss is 0.0270868, the validation accuracy is 0.9684
# after 5400 training steps, the loss is 0.0146467, the validation accuracy is 0.9664
# after 5500 training steps, the loss is 0.0297565, the validation accuracy is 0.9682
# after 5600 training steps, the loss is 0.0675844, the validation accuracy is 0.9686
# after 5700 training steps, the loss is 0.0959006, the validation accuracy is 0.9674
# after 5800 training steps, the loss is 0.255231, the validation accuracy is 0.9688
# after 5900 training steps, the loss is 0.024296, the validation accuracy is 0.9678
# after 6000 training steps, the loss is 0.195583, the validation accuracy is 0.9682
# after 6100 training steps, the loss is 0.112967, the validation accuracy is 0.9684
# after 6200 training steps, the loss is 0.0235413, the validation accuracy is 0.9702
# after 6300 training steps, the loss is 0.0772692, the validation accuracy is 0.9708
# after 6400 training steps, the loss is 0.140212, the validation accuracy is 0.9696
# after 6500 training steps, the loss is 0.0218685, the validation accuracy is 0.9722
# after 6600 training steps, the loss is 0.0355596, the validation accuracy is 0.9702
# after 6700 training steps, the loss is 0.020227, the validation accuracy is 0.9704
# after 6800 training steps, the loss is 0.0197908, the validation accuracy is 0.9696
# after 6900 training steps, the loss is 0.00693034, the validation accuracy is 0.9702
# after 7000 training steps, the loss is 0.0637072, the validation accuracy is 0.9708
# after 7100 training steps, the loss is 0.0459145, the validation accuracy is 0.9698
# after 7200 training steps, the loss is 0.0210716, the validation accuracy is 0.9696
# after 7300 training steps, the loss is 0.159541, the validation accuracy is 0.9704
# after 7400 training steps, the loss is 0.0165022, the validation accuracy is 0.9716
# after 7500 training steps, the loss is 0.0727899, the validation accuracy is 0.971
# after 7600 training steps, the loss is 0.386318, the validation accuracy is 0.9692
# after 7700 training steps, the loss is 0.0755543, the validation accuracy is 0.9704
# after 7800 training steps, the loss is 0.0215795, the validation accuracy is 0.9686
# after 7900 training steps, the loss is 0.142336, the validation accuracy is 0.9712
# after 8000 training steps, the loss is 0.0295997, the validation accuracy is 0.9696
# after 8100 training steps, the loss is 0.0279937, the validation accuracy is 0.9718
# after 8200 training steps, the loss is 0.0709234, the validation accuracy is 0.9726
# after 8300 training steps, the loss is 0.0596597, the validation accuracy is 0.973
# after 8400 training steps, the loss is 0.0179789, the validation accuracy is 0.971
# after 8500 training steps, the loss is 0.0167452, the validation accuracy is 0.9704
# after 8600 training steps, the loss is 0.013517, the validation accuracy is 0.9708
# after 8700 training steps, the loss is 0.0535606, the validation accuracy is 0.9712
# after 8800 training steps, the loss is 0.0327474, the validation accuracy is 0.9724
# after 8900 training steps, the loss is 0.0639385, the validation accuracy is 0.971
# after 9000 training steps, the loss is 0.117476, the validation accuracy is 0.9702
# after 9100 training steps, the loss is 0.0362588, the validation accuracy is 0.9698
# after 9200 training steps, the loss is 0.0297554, the validation accuracy is 0.972
# after 9300 training steps, the loss is 0.0528047, the validation accuracy is 0.9726
# after 9400 training steps, the loss is 0.0248847, the validation accuracy is 0.9744
# after 9500 training steps, the loss is 0.0933063, the validation accuracy is 0.9722
# after 9600 training steps, the loss is 0.00360819, the validation accuracy is 0.972
# after 9700 training steps, the loss is 0.0428383, the validation accuracy is 0.974
# after 9800 training steps, the loss is 0.020943, the validation accuracy is 0.974
# after 9900 training steps, the loss is 0.0194542, the validation accuracy is 0.9744
# after 10000 training steps, the loss is 0.0326659, the validation accuracy is 0.9718
# after 10100 training steps, the loss is 0.0918415, the validation accuracy is 0.9748
# after 10200 training steps, the loss is 0.076035, the validation accuracy is 0.9748
# after 10300 training steps, the loss is 0.156449, the validation accuracy is 0.9746
# after 10400 training steps, the loss is 0.114482, the validation accuracy is 0.9724
# after 10500 training steps, the loss is 0.0922276, the validation accuracy is 0.9752
# after 10600 training steps, the loss is 0.0384158, the validation accuracy is 0.9758
# after 10700 training steps, the loss is 0.0355638, the validation accuracy is 0.9744
# after 10800 training steps, the loss is 0.0402294, the validation accuracy is 0.9728
# after 10900 training steps, the loss is 0.0122917, the validation accuracy is 0.9732
# after 11000 training steps, the loss is 0.0506499, the validation accuracy is 0.9744
# after 11100 training steps, the loss is 0.180277, the validation accuracy is 0.974
# after 11200 training steps, the loss is 0.115582, the validation accuracy is 0.9736
# after 11300 training steps, the loss is 0.0148804, the validation accuracy is 0.9746
# after 11400 training steps, the loss is 0.0710114, the validation accuracy is 0.9758
# after 11500 training steps, the loss is 0.0601473, the validation accuracy is 0.9748
# after 11600 training steps, the loss is 0.108728, the validation accuracy is 0.9752
# after 11700 training steps, the loss is 0.0318302, the validation accuracy is 0.9764
# after 11800 training steps, the loss is 0.0776232, the validation accuracy is 0.9728
# after 11900 training steps, the loss is 0.0673101, the validation accuracy is 0.9722
# after 12000 training steps, the loss is 0.130494, the validation accuracy is 0.9748
# after 12100 training steps, the loss is 0.00714206, the validation accuracy is 0.9754
# after 12200 training steps, the loss is 0.00561492, the validation accuracy is 0.9742
# after 12300 training steps, the loss is 0.0227175, the validation accuracy is 0.975
# after 12400 training steps, the loss is 0.0390379, the validation accuracy is 0.9746
# after 12500 training steps, the loss is 0.0864121, the validation accuracy is 0.9738
# after 12600 training steps, the loss is 0.0433853, the validation accuracy is 0.9704
# after 12700 training steps, the loss is 0.0740443, the validation accuracy is 0.9746
# after 12800 training steps, the loss is 0.0217098, the validation accuracy is 0.9736
# after 12900 training steps, the loss is 0.0128319, the validation accuracy is 0.9756
# after 13000 training steps, the loss is 0.0392452, the validation accuracy is 0.9752
# after 13100 training steps, the loss is 0.0219478, the validation accuracy is 0.9718
# after 13200 training steps, the loss is 0.0234996, the validation accuracy is 0.9754
# after 13300 training steps, the loss is 0.0105872, the validation accuracy is 0.976
# after 13400 training steps, the loss is 0.0162313, the validation accuracy is 0.974
# after 13500 training steps, the loss is 0.0259186, the validation accuracy is 0.9758
# after 13600 training steps, the loss is 0.0727499, the validation accuracy is 0.9758
# after 13700 training steps, the loss is 0.0260391, the validation accuracy is 0.9756
# after 13800 training steps, the loss is 0.104532, the validation accuracy is 0.9754
# after 13900 training steps, the loss is 0.10455, the validation accuracy is 0.9742
# after 14000 training steps, the loss is 0.048268, the validation accuracy is 0.9748
# after 14100 training steps, the loss is 0.047662, the validation accuracy is 0.977
# after 14200 training steps, the loss is 0.0633997, the validation accuracy is 0.9744
# after 14300 training steps, the loss is 0.0282308, the validation accuracy is 0.974
# after 14400 training steps, the loss is 0.00842896, the validation accuracy is 0.9744
# after 14500 training steps, the loss is 0.0363279, the validation accuracy is 0.9754
# after 14600 training steps, the loss is 0.0219772, the validation accuracy is 0.9752
# after 14700 training steps, the loss is 0.113849, the validation accuracy is 0.9756
# after 14800 training steps, the loss is 0.0841659, the validation accuracy is 0.9764
# after 14900 training steps, the loss is 0.0114585, the validation accuracy is 0.9748
# after 15000 training steps, the loss is 0.0144145, the validation accuracy is 0.9758
# after 15100 training steps, the loss is 0.0140327, the validation accuracy is 0.975
# after 15200 training steps, the loss is 0.0138657, the validation accuracy is 0.978
# after 15300 training steps, the loss is 0.0134822, the validation accuracy is 0.9762
# after 15400 training steps, the loss is 0.108485, the validation accuracy is 0.9756
# after 15500 training steps, the loss is 0.0223242, the validation accuracy is 0.9778
# after 15600 training steps, the loss is 0.0130501, the validation accuracy is 0.9772
# after 15700 training steps, the loss is 0.0714105, the validation accuracy is 0.9758
# after 15800 training steps, the loss is 0.0331264, the validation accuracy is 0.976
# after 15900 training steps, the loss is 0.0461827, the validation accuracy is 0.9772
# after 16000 training steps, the loss is 0.0199712, the validation accuracy is 0.9768
# after 16100 training steps, the loss is 0.0663069, the validation accuracy is 0.976
# after 16200 training steps, the loss is 0.000928082, the validation accuracy is 0.9776
# after 16300 training steps, the loss is 0.0339133, the validation accuracy is 0.9766
# after 16400 training steps, the loss is 0.00832795, the validation accuracy is 0.9762
# after 16500 training steps, the loss is 0.0152125, the validation accuracy is 0.9768
# after 16600 training steps, the loss is 0.0113413, the validation accuracy is 0.9786
# after 16700 training steps, the loss is 0.0213533, the validation accuracy is 0.9776
# after 16800 training steps, the loss is 0.202007, the validation accuracy is 0.9754
# after 16900 training steps, the loss is 0.0100471, the validation accuracy is 0.9784
# after 17000 training steps, the loss is 0.0407968, the validation accuracy is 0.976
# after 17100 training steps, the loss is 0.0427878, the validation accuracy is 0.9756
# after 17200 training steps, the loss is 0.00400886, the validation accuracy is 0.978
# after 17300 training steps, the loss is 0.00563565, the validation accuracy is 0.977
# after 17400 training steps, the loss is 0.0260983, the validation accuracy is 0.978
# after 17500 training steps, the loss is 0.0621458, the validation accuracy is 0.9776
# after 17600 training steps, the loss is 0.0089828, the validation accuracy is 0.9782
# after 17700 training steps, the loss is 0.0397361, the validation accuracy is 0.9786
# after 17800 training steps, the loss is 0.0305955, the validation accuracy is 0.975
# after 17900 training steps, the loss is 0.00587194, the validation accuracy is 0.9796
# after 18000 training steps, the loss is 0.00228045, the validation accuracy is 0.977
# after 18100 training steps, the loss is 0.0141611, the validation accuracy is 0.9778
# after 18200 training steps, the loss is 0.00507596, the validation accuracy is 0.9776
# after 18300 training steps, the loss is 0.0378333, the validation accuracy is 0.9784
# after 18400 training steps, the loss is 0.02146, the validation accuracy is 0.978
# after 18500 training steps, the loss is 0.0108897, the validation accuracy is 0.9782
# after 18600 training steps, the loss is 0.0526265, the validation accuracy is 0.9772
# after 18700 training steps, the loss is 0.0287904, the validation accuracy is 0.9794
# after 18800 training steps, the loss is 0.00888639, the validation accuracy is 0.9792
# after 18900 training steps, the loss is 0.00417531, the validation accuracy is 0.9794
# after 19000 training steps, the loss is 0.0645241, the validation accuracy is 0.9776
# after 19100 training steps, the loss is 0.0114696, the validation accuracy is 0.9768
# after 19200 training steps, the loss is 0.0103414, the validation accuracy is 0.9778
# after 19300 training steps, the loss is 0.0174371, the validation accuracy is 0.9766
# after 19400 training steps, the loss is 0.00345159, the validation accuracy is 0.9778
# after 19500 training steps, the loss is 0.0094564, the validation accuracy is 0.9766
# after 19600 training steps, the loss is 0.0252501, the validation accuracy is 0.9772
# after 19700 training steps, the loss is 0.0420382, the validation accuracy is 0.9758
# after 19800 training steps, the loss is 0.0077823, the validation accuracy is 0.9776
# after 19900 training steps, the loss is 0.00349406, the validation accuracy is 0.9784
# the traning is finish!
# the train accuracy is : 0.99265456
# the test accuracy is : 0.9746

# %% [markdown]
# 可以看到效果，准确率达到了97%左右，比之前提高了3%~

# %% [markdown]
# ## 下面单纯增加隐层数量 增加一层神经元个数为100

# %%
train(batch_size=32, training_step=1000, lr=0.3, hidden1=100, hidden2=100)
# Out:
# after 100 training steps, the loss is 0.50878, the validation accuracy is 0.7608
# after 200 training steps, the loss is 0.859833, the validation accuracy is 0.8164
# after 300 training steps, the loss is 0.080929, the validation accuracy is 0.921
# after 400 training steps, the loss is 0.347211, the validation accuracy is 0.9296
# after 500 training steps, the loss is 0.351842, the validation accuracy is 0.9358
# after 600 training steps, the loss is 0.117844, the validation accuracy is 0.9378
# after 700 training steps, the loss is 0.233173, the validation accuracy is 0.9324
# after 800 training steps, the loss is 0.262243, the validation accuracy is 0.936
# after 900 training steps, the loss is 0.190898, the validation accuracy is 0.9394
# the traning is finish!
# the train accuracy is : 0.948
# the test accuracy is : 0.9431

# %% [markdown]
# 仅仅增加隐层数量效果不没有预期的好，准确率也只有94%左右

# %% [markdown]
# ## 在增加隐层的基础上，增加训练次数并降低学习率

# %%
train(batch_size=32, training_step=20000, lr=0.1, hidden1=100, hidden2=100)
# Out:
# after 100 training steps, the loss is 0.484106, the validation accuracy is 0.8332
# after 200 training steps, the loss is 0.241133, the validation accuracy is 0.8864
# after 300 training steps, the loss is 0.245671, the validation accuracy is 0.8934
# after 400 training steps, the loss is 0.409385, the validation accuracy is 0.916
# after 500 training steps, the loss is 0.0724811, the validation accuracy is 0.9228
# after 600 training steps, the loss is 0.252472, the validation accuracy is 0.9252
# after 700 training steps, the loss is 0.155133, the validation accuracy is 0.9294
# after 800 training steps, the loss is 0.149752, the validation accuracy is 0.9374
# after 900 training steps, the loss is 0.128861, the validation accuracy is 0.9416
# after 1000 training steps, the loss is 0.434686, the validation accuracy is 0.935
# after 1100 training steps, the loss is 0.779429, the validation accuracy is 0.9066
# after 1200 training steps, the loss is 0.15246, the validation accuracy is 0.9464
# after 1300 training steps, the loss is 0.100095, the validation accuracy is 0.9502
# after 1400 training steps, the loss is 0.0852092, the validation accuracy is 0.9518
# after 1500 training steps, the loss is 0.173813, the validation accuracy is 0.952
# after 1600 training steps, the loss is 0.129155, the validation accuracy is 0.9534
# after 1700 training steps, the loss is 0.407228, the validation accuracy is 0.9516
# after 1800 training steps, the loss is 0.139866, the validation accuracy is 0.9532
# after 1900 training steps, the loss is 0.0330618, the validation accuracy is 0.957
# after 2000 training steps, the loss is 0.179023, the validation accuracy is 0.9572
# after 2100 training steps, the loss is 0.182396, the validation accuracy is 0.9576
# after 2200 training steps, the loss is 0.0789965, the validation accuracy is 0.9604
# after 2300 training steps, the loss is 0.0889938, the validation accuracy is 0.958
# after 2400 training steps, the loss is 0.275802, the validation accuracy is 0.9636
# after 2500 training steps, the loss is 0.261613, the validation accuracy is 0.963
# after 2600 training steps, the loss is 0.0439816, the validation accuracy is 0.9638
# after 2700 training steps, the loss is 0.0474079, the validation accuracy is 0.9634
# after 2800 training steps, the loss is 0.0944344, the validation accuracy is 0.9614
# after 2900 training steps, the loss is 0.0748579, the validation accuracy is 0.9574
# after 3000 training steps, the loss is 0.34144, the validation accuracy is 0.9638
# after 3100 training steps, the loss is 0.138502, the validation accuracy is 0.9684
# after 3200 training steps, the loss is 0.0070896, the validation accuracy is 0.9658
# after 3300 training steps, the loss is 0.187994, the validation accuracy is 0.9622
# after 3400 training steps, the loss is 0.11566, the validation accuracy is 0.9624
# after 3500 training steps, the loss is 0.0813069, the validation accuracy is 0.9658
# after 3600 training steps, the loss is 0.172594, the validation accuracy is 0.9642
# after 3700 training steps, the loss is 0.13528, the validation accuracy is 0.967
# after 3800 training steps, the loss is 0.0437732, the validation accuracy is 0.9654
# after 3900 training steps, the loss is 0.0899528, the validation accuracy is 0.9694
# after 4000 training steps, the loss is 0.255174, the validation accuracy is 0.9684
# after 4100 training steps, the loss is 0.122073, the validation accuracy is 0.9686
# after 4200 training steps, the loss is 0.04911, the validation accuracy is 0.9712
# after 4300 training steps, the loss is 0.162582, the validation accuracy is 0.9716
# after 4400 training steps, the loss is 0.375835, the validation accuracy is 0.9672
# after 4500 training steps, the loss is 0.103688, the validation accuracy is 0.9642
# after 4600 training steps, the loss is 0.0170668, the validation accuracy is 0.9728
# after 4700 training steps, the loss is 0.175796, the validation accuracy is 0.9682
# after 4800 training steps, the loss is 0.0234767, the validation accuracy is 0.9664
# after 4900 training steps, the loss is 0.0807535, the validation accuracy is 0.9678
# after 5000 training steps, the loss is 0.0224654, the validation accuracy is 0.9722
# after 5100 training steps, the loss is 0.101078, the validation accuracy is 0.9718
# after 5200 training steps, the loss is 0.22684, the validation accuracy is 0.964
# after 5300 training steps, the loss is 0.0120438, the validation accuracy is 0.9702
# after 5400 training steps, the loss is 0.0353628, the validation accuracy is 0.9734
# after 5500 training steps, the loss is 0.314662, the validation accuracy is 0.9662
# after 5600 training steps, the loss is 0.0319191, the validation accuracy is 0.966
# after 5700 training steps, the loss is 0.057151, the validation accuracy is 0.9682
# after 5800 training steps, the loss is 0.0192796, the validation accuracy is 0.9726
# after 5900 training steps, the loss is 0.23275, the validation accuracy is 0.9692
# after 6000 training steps, the loss is 0.0297086, the validation accuracy is 0.973
# after 6100 training steps, the loss is 0.0107366, the validation accuracy is 0.9724
# after 6200 training steps, the loss is 0.0333983, the validation accuracy is 0.9752
# after 6300 training steps, the loss is 0.180429, the validation accuracy is 0.9724
# after 6400 training steps, the loss is 0.0552758, the validation accuracy is 0.971
# after 6500 training steps, the loss is 0.115108, the validation accuracy is 0.9738
# after 6600 training steps, the loss is 0.402119, the validation accuracy is 0.9754
# after 6700 training steps, the loss is 0.0389485, the validation accuracy is 0.9716
# after 6800 training steps, the loss is 0.156107, the validation accuracy is 0.9726
# after 6900 training steps, the loss is 0.016856, the validation accuracy is 0.9748
# after 7000 training steps, the loss is 0.0666216, the validation accuracy is 0.9738
# after 7100 training steps, the loss is 0.00666241, the validation accuracy is 0.9728
# after 7200 training steps, the loss is 0.110152, the validation accuracy is 0.9718
# after 7300 training steps, the loss is 0.00862379, the validation accuracy is 0.9732
# after 7400 training steps, the loss is 0.0381514, the validation accuracy is 0.977
# after 7500 training steps, the loss is 0.0378244, the validation accuracy is 0.9746
# after 7600 training steps, the loss is 0.0209102, the validation accuracy is 0.9776
# after 7700 training steps, the loss is 0.0544453, the validation accuracy is 0.9762
# after 7800 training steps, the loss is 0.18108, the validation accuracy is 0.9728
# after 7900 training steps, the loss is 0.0235434, the validation accuracy is 0.9744
# after 8000 training steps, the loss is 0.0138691, the validation accuracy is 0.973
# after 8100 training steps, the loss is 0.19603, the validation accuracy is 0.9702
# after 8200 training steps, the loss is 0.0702479, the validation accuracy is 0.9752
# after 8300 training steps, the loss is 0.00285936, the validation accuracy is 0.9746
# after 8400 training steps, the loss is 0.0564236, the validation accuracy is 0.9756
# after 8500 training steps, the loss is 0.0707947, the validation accuracy is 0.9724
# after 8600 training steps, the loss is 0.0896425, the validation accuracy is 0.9738
# after 8700 training steps, the loss is 0.060535, the validation accuracy is 0.975
# after 8800 training steps, the loss is 0.0583098, the validation accuracy is 0.9756
# after 8900 training steps, the loss is 0.118645, the validation accuracy is 0.9768
# after 9000 training steps, the loss is 0.0182235, the validation accuracy is 0.9754
# after 9100 training steps, the loss is 0.012595, the validation accuracy is 0.9772
# after 9200 training steps, the loss is 0.00807092, the validation accuracy is 0.9756
# after 9300 training steps, the loss is 0.00859745, the validation accuracy is 0.9774
# after 9400 training steps, the loss is 0.00718277, the validation accuracy is 0.9762
# after 9500 training steps, the loss is 0.035623, the validation accuracy is 0.9748
# after 9600 training steps, the loss is 0.0132602, the validation accuracy is 0.9776
# after 9700 training steps, the loss is 0.146018, the validation accuracy is 0.9774
# after 9800 training steps, the loss is 0.0900503, the validation accuracy is 0.9746
# after 9900 training steps, the loss is 0.0206306, the validation accuracy is 0.9738
# after 10000 training steps, the loss is 0.0162476, the validation accuracy is 0.975
# after 10100 training steps, the loss is 0.0113536, the validation accuracy is 0.9732
# after 10200 training steps, the loss is 0.0131036, the validation accuracy is 0.9762
# after 10300 training steps, the loss is 0.0130197, the validation accuracy is 0.9754
# after 10400 training steps, the loss is 0.0715552, the validation accuracy is 0.9772
# after 10500 training steps, the loss is 0.000424226, the validation accuracy is 0.9774
# after 10600 training steps, the loss is 0.0356783, the validation accuracy is 0.977
# after 10700 training steps, the loss is 0.00535564, the validation accuracy is 0.9758
# after 10800 training steps, the loss is 0.0167313, the validation accuracy is 0.9758
# after 10900 training steps, the loss is 0.00348134, the validation accuracy is 0.9762
# after 11000 training steps, the loss is 0.136834, the validation accuracy is 0.9746
# after 11100 training steps, the loss is 0.124987, the validation accuracy is 0.9766
# after 11200 training steps, the loss is 0.00260198, the validation accuracy is 0.9758
# after 11300 training steps, the loss is 0.0109446, the validation accuracy is 0.9782
# after 11400 training steps, the loss is 0.0310759, the validation accuracy is 0.9782
# after 11500 training steps, the loss is 0.0802724, the validation accuracy is 0.9756
# after 11600 training steps, the loss is 0.0164049, the validation accuracy is 0.976
# after 11700 training steps, the loss is 0.0351782, the validation accuracy is 0.974
# after 11800 training steps, the loss is 0.00232944, the validation accuracy is 0.9776
# after 11900 training steps, the loss is 0.00750093, the validation accuracy is 0.9774
# after 12000 training steps, the loss is 0.0238196, the validation accuracy is 0.9778
# after 12100 training steps, the loss is 0.00631838, the validation accuracy is 0.9768
# after 12200 training steps, the loss is 0.0135486, the validation accuracy is 0.9738
# after 12300 training steps, the loss is 0.376625, the validation accuracy is 0.9766
# after 12400 training steps, the loss is 0.0361044, the validation accuracy is 0.9776
# after 12500 training steps, the loss is 0.0126839, the validation accuracy is 0.9784
# after 12600 training steps, the loss is 0.0288802, the validation accuracy is 0.98
# after 12700 training steps, the loss is 0.0440597, the validation accuracy is 0.9776
# after 12800 training steps, the loss is 0.0083629, the validation accuracy is 0.9784
# after 12900 training steps, the loss is 0.00396246, the validation accuracy is 0.9776
# after 13000 training steps, the loss is 0.180435, the validation accuracy is 0.9752
# after 13100 training steps, the loss is 0.00873203, the validation accuracy is 0.9782
# after 13200 training steps, the loss is 0.0552286, the validation accuracy is 0.9774
# after 13300 training steps, the loss is 0.00104056, the validation accuracy is 0.9782
# after 13400 training steps, the loss is 0.015178, the validation accuracy is 0.9784
# after 13500 training steps, the loss is 0.00491303, the validation accuracy is 0.9766
# after 13600 training steps, the loss is 0.000808147, the validation accuracy is 0.9784
# after 13700 training steps, the loss is 0.00256227, the validation accuracy is 0.9768
# after 13800 training steps, the loss is 0.0101674, the validation accuracy is 0.9796
# after 13900 training steps, the loss is 0.0285123, the validation accuracy is 0.9786
# after 14000 training steps, the loss is 0.00373495, the validation accuracy is 0.9768
# after 14100 training steps, the loss is 0.0482627, the validation accuracy is 0.977
# after 14200 training steps, the loss is 0.0121593, the validation accuracy is 0.977
# after 14300 training steps, the loss is 0.0505067, the validation accuracy is 0.9798
# after 14400 training steps, the loss is 0.0309386, the validation accuracy is 0.9786
# after 14500 training steps, the loss is 0.00173933, the validation accuracy is 0.9784
# after 14600 training steps, the loss is 0.0890835, the validation accuracy is 0.9772
# after 14700 training steps, the loss is 0.0596153, the validation accuracy is 0.9786
# after 14800 training steps, the loss is 0.00830057, the validation accuracy is 0.977
# after 14900 training steps, the loss is 0.0107144, the validation accuracy is 0.9772
# after 15000 training steps, the loss is 0.000547978, the validation accuracy is 0.9772
# after 15100 training steps, the loss is 0.0177229, the validation accuracy is 0.9784
# after 15200 training steps, the loss is 0.00191486, the validation accuracy is 0.9774
# after 15300 training steps, the loss is 0.0114486, the validation accuracy is 0.9768
# after 15400 training steps, the loss is 0.0174403, the validation accuracy is 0.9776
# after 15500 training steps, the loss is 0.0183599, the validation accuracy is 0.976
# after 15600 training steps, the loss is 0.0622134, the validation accuracy is 0.9766
# after 15700 training steps, the loss is 0.0128727, the validation accuracy is 0.9792
# after 15800 training steps, the loss is 0.0023177, the validation accuracy is 0.9794
# after 15900 training steps, the loss is 0.00477827, the validation accuracy is 0.9786
# after 16000 training steps, the loss is 0.00297912, the validation accuracy is 0.9798
# after 16100 training steps, the loss is 0.00538169, the validation accuracy is 0.979
# after 16200 training steps, the loss is 0.0453959, the validation accuracy is 0.9786
# after 16300 training steps, the loss is 0.00124648, the validation accuracy is 0.9758
# after 16400 training steps, the loss is 0.0308762, the validation accuracy is 0.979
# after 16500 training steps, the loss is 0.000596501, the validation accuracy is 0.9784
# after 16600 training steps, the loss is 0.0232269, the validation accuracy is 0.9758
# after 16700 training steps, the loss is 0.000703423, the validation accuracy is 0.976
# after 16800 training steps, the loss is 0.018408, the validation accuracy is 0.9764
# after 16900 training steps, the loss is 0.0685322, the validation accuracy is 0.9776
# after 17000 training steps, the loss is 0.0466873, the validation accuracy is 0.9782
# after 17100 training steps, the loss is 0.00532077, the validation accuracy is 0.978
# after 17200 training steps, the loss is 0.00862418, the validation accuracy is 0.9778
# after 17300 training steps, the loss is 0.0182435, the validation accuracy is 0.9758
# after 17400 training steps, the loss is 0.00170785, the validation accuracy is 0.9786
# after 17500 training steps, the loss is 0.00178063, the validation accuracy is 0.9752
# after 17600 training steps, the loss is 0.000792232, the validation accuracy is 0.9788
# after 17700 training steps, the loss is 0.000283693, the validation accuracy is 0.98
# after 17800 training steps, the loss is 0.0175107, the validation accuracy is 0.9804
# after 17900 training steps, the loss is 0.0357822, the validation accuracy is 0.9756
# after 18000 training steps, the loss is 0.0324977, the validation accuracy is 0.9798
# after 18100 training steps, the loss is 0.00173753, the validation accuracy is 0.9764
# after 18200 training steps, the loss is 0.127197, the validation accuracy is 0.9752
# after 18300 training steps, the loss is 0.00132118, the validation accuracy is 0.9776
# after 18400 training steps, the loss is 0.010814, the validation accuracy is 0.9788
# after 18500 training steps, the loss is 0.0133111, the validation accuracy is 0.9766
# after 18600 training steps, the loss is 0.000570721, the validation accuracy is 0.9774
# after 18700 training steps, the loss is 0.0270749, the validation accuracy is 0.9782
# after 18800 training steps, the loss is 0.0246873, the validation accuracy is 0.9768
# after 18900 training steps, the loss is 0.00181164, the validation accuracy is 0.9792
# after 19000 training steps, the loss is 0.00398105, the validation accuracy is 0.9758
# after 19100 training steps, the loss is 0.0178504, the validation accuracy is 0.9786
# after 19200 training steps, the loss is 0.0108766, the validation accuracy is 0.98
# after 19300 training steps, the loss is 0.00716541, the validation accuracy is 0.9794
# after 19400 training steps, the loss is 0.0102167, the validation accuracy is 0.98
# after 19500 training steps, the loss is 0.00191976, the validation accuracy is 0.9792
# after 19600 training steps, the loss is 0.00502659, the validation accuracy is 0.9808
# after 19700 training steps, the loss is 0.0254301, the validation accuracy is 0.9798
# after 19800 training steps, the loss is 0.00265462, the validation accuracy is 0.9806
# after 19900 training steps, the loss is 0.048022, the validation accuracy is 0.9764
# the traning is finish!
# the train accuracy is : 0.9976182
# the test accuracy is : 0.9791

# %% [markdown]
# 可以看到准确率达到了97.9%,接近98%，同时在10000次左右效果已经很好，下面为了减少训练时间，训练次数采用10000次

# %% [markdown]
# ## 在上面基础上增加神经元数量

# %%
train(batch_size=32, training_step=10000, lr=0.1, hidden1=1000, hidden2=1000)
# Out:
# after 100 training steps, the loss is 0.444278, the validation accuracy is 0.8916
# after 200 training steps, the loss is 0.367151, the validation accuracy is 0.9238
# after 300 training steps, the loss is 0.330017, the validation accuracy is 0.9302
# after 400 training steps, the loss is 0.0342281, the validation accuracy is 0.9412
# after 500 training steps, the loss is 0.058277, the validation accuracy is 0.9492
# after 600 training steps, the loss is 0.180861, the validation accuracy is 0.9508
# after 700 training steps, the loss is 0.111979, the validation accuracy is 0.9528
# after 800 training steps, the loss is 0.128166, the validation accuracy is 0.957
# after 900 training steps, the loss is 0.036341, the validation accuracy is 0.9598
# after 1000 training steps, the loss is 0.234459, the validation accuracy is 0.958
# after 1100 training steps, the loss is 0.0309909, the validation accuracy is 0.964
# after 1200 training steps, the loss is 0.143733, the validation accuracy is 0.9676
# after 1300 training steps, the loss is 0.355197, the validation accuracy is 0.9638
# after 1400 training steps, the loss is 0.0709762, the validation accuracy is 0.9632
# after 1500 training steps, the loss is 0.0749779, the validation accuracy is 0.9578
# after 1600 training steps, the loss is 0.0417128, the validation accuracy is 0.9688
# after 1700 training steps, the loss is 0.123991, the validation accuracy is 0.9656
# after 1800 training steps, the loss is 0.0244555, the validation accuracy is 0.9702
# after 1900 training steps, the loss is 0.00774594, the validation accuracy is 0.9734
# after 2000 training steps, the loss is 0.106863, the validation accuracy is 0.9714
# after 2100 training steps, the loss is 0.101655, the validation accuracy is 0.9718
# after 2200 training steps, the loss is 0.132504, the validation accuracy is 0.9712
# after 2300 training steps, the loss is 0.00845973, the validation accuracy is 0.9698
# after 2400 training steps, the loss is 0.113781, the validation accuracy is 0.9696
# after 2500 training steps, the loss is 0.0364488, the validation accuracy is 0.9744
# after 2600 training steps, the loss is 0.0712085, the validation accuracy is 0.972
# after 2700 training steps, the loss is 0.0111513, the validation accuracy is 0.9752
# after 2800 training steps, the loss is 0.00815834, the validation accuracy is 0.9758
# after 2900 training steps, the loss is 0.0191157, the validation accuracy is 0.9726
# after 3000 training steps, the loss is 0.0549558, the validation accuracy is 0.9776
# after 3100 training steps, the loss is 0.00285851, the validation accuracy is 0.976
# after 3200 training steps, the loss is 0.00306574, the validation accuracy is 0.9744
# after 3300 training steps, the loss is 0.0118071, the validation accuracy is 0.9764
# after 3400 training steps, the loss is 0.0624837, the validation accuracy is 0.974
# after 3500 training steps, the loss is 0.0244924, the validation accuracy is 0.9754
# after 3600 training steps, the loss is 0.0187385, the validation accuracy is 0.974
# after 3700 training steps, the loss is 0.022807, the validation accuracy is 0.9758
# after 3800 training steps, the loss is 0.0246752, the validation accuracy is 0.9762
# after 3900 training steps, the loss is 0.0247045, the validation accuracy is 0.974
# after 4000 training steps, the loss is 0.0132084, the validation accuracy is 0.9724
# after 4100 training steps, the loss is 0.00846116, the validation accuracy is 0.9778
# after 4200 training steps, the loss is 0.0084315, the validation accuracy is 0.9772
# after 4300 training steps, the loss is 0.01071, the validation accuracy is 0.9794
# after 4400 training steps, the loss is 0.0184616, the validation accuracy is 0.9778
# after 4500 training steps, the loss is 0.00744342, the validation accuracy is 0.979
# after 4600 training steps, the loss is 0.00153443, the validation accuracy is 0.98
# after 4700 training steps, the loss is 0.0196321, the validation accuracy is 0.9786
# after 4800 training steps, the loss is 0.00997719, the validation accuracy is 0.9794
# after 4900 training steps, the loss is 0.0087919, the validation accuracy is 0.9812
# after 5000 training steps, the loss is 0.00880508, the validation accuracy is 0.9818
# after 5100 training steps, the loss is 0.131781, the validation accuracy is 0.9782
# after 5200 training steps, the loss is 0.0184427, the validation accuracy is 0.9782
# after 5300 training steps, the loss is 0.00275738, the validation accuracy is 0.978
# after 5400 training steps, the loss is 0.0395364, the validation accuracy is 0.9776
# after 5500 training steps, the loss is 0.00473397, the validation accuracy is 0.9784
# after 5600 training steps, the loss is 0.00752203, the validation accuracy is 0.9792
# after 5700 training steps, the loss is 0.0119683, the validation accuracy is 0.9818
# after 5800 training steps, the loss is 0.00408921, the validation accuracy is 0.9792
# after 5900 training steps, the loss is 0.00592655, the validation accuracy is 0.9788
# after 6000 training steps, the loss is 0.0425917, the validation accuracy is 0.9826
# after 6100 training steps, the loss is 0.010265, the validation accuracy is 0.981
# after 6200 training steps, the loss is 0.00989603, the validation accuracy is 0.9818
# after 6300 training steps, the loss is 0.0298227, the validation accuracy is 0.979
# after 6400 training steps, the loss is 0.00350858, the validation accuracy is 0.981
# after 6500 training steps, the loss is 0.00636994, the validation accuracy is 0.9812
# after 6600 training steps, the loss is 0.00110379, the validation accuracy is 0.9804
# after 6700 training steps, the loss is 0.002919, the validation accuracy is 0.9808
# after 6800 training steps, the loss is 0.00461386, the validation accuracy is 0.9816
# after 6900 training steps, the loss is 0.0180555, the validation accuracy is 0.981
# after 7000 training steps, the loss is 0.00258939, the validation accuracy is 0.9794
# after 7100 training steps, the loss is 0.00648281, the validation accuracy is 0.977
# after 7200 training steps, the loss is 0.00743773, the validation accuracy is 0.9794
# after 7300 training steps, the loss is 0.00134814, the validation accuracy is 0.9816
# after 7400 training steps, the loss is 0.0176965, the validation accuracy is 0.981
# after 7500 training steps, the loss is 0.00331806, the validation accuracy is 0.9816
# after 7600 training steps, the loss is 0.00274459, the validation accuracy is 0.9814
# after 7700 training steps, the loss is 0.00091314, the validation accuracy is 0.9806
# after 7800 training steps, the loss is 0.00757217, the validation accuracy is 0.9824
# after 7900 training steps, the loss is 0.00629462, the validation accuracy is 0.9822
# after 8000 training steps, the loss is 0.00225828, the validation accuracy is 0.9816
# after 8100 training steps, the loss is 0.00135698, the validation accuracy is 0.9814
# after 8200 training steps, the loss is 0.0029253, the validation accuracy is 0.9812
# after 8300 training steps, the loss is 0.00701243, the validation accuracy is 0.9824
# after 8400 training steps, the loss is 0.000589422, the validation accuracy is 0.982
# after 8500 training steps, the loss is 0.00361816, the validation accuracy is 0.9836
# after 8600 training steps, the loss is 0.0290761, the validation accuracy is 0.9824
# after 8700 training steps, the loss is 0.00936476, the validation accuracy is 0.9834
# after 8800 training steps, the loss is 0.00656789, the validation accuracy is 0.9828
# after 8900 training steps, the loss is 0.00241335, the validation accuracy is 0.9826
# after 9000 training steps, the loss is 0.0003397, the validation accuracy is 0.9826
# after 9100 training steps, the loss is 0.000495733, the validation accuracy is 0.9828
# after 9200 training steps, the loss is 0.00249445, the validation accuracy is 0.9834
# after 9300 training steps, the loss is 0.00329033, the validation accuracy is 0.9832
# after 9400 training steps, the loss is 0.00721204, the validation accuracy is 0.9826
# after 9500 training steps, the loss is 0.000204314, the validation accuracy is 0.9828
# after 9600 training steps, the loss is 0.000668312, the validation accuracy is 0.9836
# after 9700 training steps, the loss is 0.000796454, the validation accuracy is 0.9846
# after 9800 training steps, the loss is 0.000405064, the validation accuracy is 0.9834
# after 9900 training steps, the loss is 0.000898366, the validation accuracy is 0.9832
# the traning is finish!
# the train accuracy is : 0.9999091
# the test accuracy is : 0.9803

# %% [markdown]
# 上面使用了10000次训练，两层神经元，每层神经元个数为1000个，训练时间较长，最终在测试集上的准确率可以达到98%！！训练集的准确率已经约为1.0

# %% [markdown]
# ## 在上面的基础上增加正则项，首先为L1正则,不再增加隐层

# %%
train(batch_size=32, training_step=1000, lr=0.1, hidden1=1000, lambda_flag='l1',lambda_value=0.01)
# Out:
# after 100 training steps, the loss is 1.96987, the validation accuracy is 0.8716
# after 200 training steps, the loss is 1.06809, the validation accuracy is 0.8314
# after 300 training steps, the loss is 1.05262, the validation accuracy is 0.8226
# after 400 training steps, the loss is 1.07248, the validation accuracy is 0.851
# after 500 training steps, the loss is 1.04777, the validation accuracy is 0.859
# after 600 training steps, the loss is 0.992822, the validation accuracy is 0.8328
# after 700 training steps, the loss is 1.13705, the validation accuracy is 0.8958
# after 800 training steps, the loss is 0.767784, the validation accuracy is 0.8972
# after 900 training steps, the loss is 0.70365, the validation accuracy is 0.9012
# the traning is finish!
# the train accuracy is : 0.88174546
# the test accuracy is : 0.8917

# %% [markdown]
# 效果并不是特别好！只有约89%的准确率

# %% [markdown]
# ## 改为L2正则试一试

# %%
train(batch_size=32, training_step=1000, lr=0.1, hidden1=1000, lambda_flag='l2',lambda_value=0.01)
# Out:
# after 100 training steps, the loss is 1.0163, the validation accuracy is 0.8728
# after 200 training steps, the loss is 0.768788, the validation accuracy is 0.9044
# after 300 training steps, the loss is 0.532562, the validation accuracy is 0.9216
# after 400 training steps, the loss is 0.676842, the validation accuracy is 0.924
# after 500 training steps, the loss is 0.501241, the validation accuracy is 0.9298
# after 600 training steps, the loss is 0.30376, the validation accuracy is 0.925
# after 700 training steps, the loss is 0.307959, the validation accuracy is 0.937
# after 800 training steps, the loss is 0.382548, the validation accuracy is 0.9408
# after 900 training steps, the loss is 0.34071, the validation accuracy is 0.9382
# the traning is finish!
# the train accuracy is : 0.94078183
# the test accuracy is : 0.9415

# %% [markdown]
# L2正则比L1正则效果好很多，准确率为94%

# %% [markdown]
# ## 改变初始化方式

# %%
train(batch_size=32, training_step=1000, lr=0.1,initial_way=MSRA, hidden1=100, lambda_flag='l2',lambda_value=0.01)
# Out:
# after 100 training steps, the loss is 0.88325, the validation accuracy is 0.852
# after 200 training steps, the loss is 0.576833, the validation accuracy is 0.8774
# after 300 training steps, the loss is 0.304504, the validation accuracy is 0.8956
# after 400 training steps, the loss is 0.591831, the validation accuracy is 0.9078
# after 500 training steps, the loss is 0.47441, the validation accuracy is 0.9102
# after 600 training steps, the loss is 0.700314, the validation accuracy is 0.9036
# after 700 training steps, the loss is 0.408681, the validation accuracy is 0.9116
# after 800 training steps, the loss is 0.253816, the validation accuracy is 0.9102
# after 900 training steps, the loss is 0.318185, the validation accuracy is 0.9202
# the traning is finish!
# the train accuracy is : 0.9107091
# the test accuracy is : 0.9109

# %%
train(batch_size=32, training_step=1000, lr=0.1,initial_way=Xavier, hidden1=100, lambda_flag='l2',lambda_value=0.01)
# Out:
# after 100 training steps, the loss is 0.850773, the validation accuracy is 0.8588
# after 200 training steps, the loss is 0.385894, the validation accuracy is 0.8858
# after 300 training steps, the loss is 0.348053, the validation accuracy is 0.8932
# after 400 training steps, the loss is 0.340069, the validation accuracy is 0.901
# after 500 training steps, the loss is 0.593027, the validation accuracy is 0.9
# after 600 training steps, the loss is 0.401246, the validation accuracy is 0.9138
# after 700 training steps, the loss is 0.659674, the validation accuracy is 0.9118
# after 800 training steps, the loss is 0.392728, the validation accuracy is 0.9166
# after 900 training steps, the loss is 0.34493, the validation accuracy is 0.9152
# the traning is finish!
# the train accuracy is : 0.90572727
# the test accuracy is : 0.911

# %% [markdown]
# 可以看到效果也没有预期的好，甚至没有最初的模型准确率高。

# %% [markdown]
# ## 综合以上尝试，考虑把模型复杂化，参数选择为训练20000步，lr=0.01，使用L2正则，初始化方式为高斯,使用双隐层，神经元个数为1000

# %%
train(batch_size=32, training_step=20000, lr=0.01, lambda_flag='l2', lambda_value=0.01,hidden1=1000, hidden2=1000)
# Out:
# after 100 training steps, the loss is 0.920323, the validation accuracy is 0.8296
# after 200 training steps, the loss is 0.968853, the validation accuracy is 0.8774
# after 300 training steps, the loss is 0.746169, the validation accuracy is 0.8988
# after 400 training steps, the loss is 0.648315, the validation accuracy is 0.8982
# after 500 training steps, the loss is 0.547964, the validation accuracy is 0.9106
# after 600 training steps, the loss is 0.766745, the validation accuracy is 0.916
# after 700 training steps, the loss is 0.792773, the validation accuracy is 0.9224
# after 800 training steps, the loss is 0.681362, the validation accuracy is 0.9282
# after 900 training steps, the loss is 0.417354, the validation accuracy is 0.9316
# after 1000 training steps, the loss is 0.557507, the validation accuracy is 0.9332
# after 1100 training steps, the loss is 0.362353, the validation accuracy is 0.9374
# after 1200 training steps, the loss is 0.412011, the validation accuracy is 0.9394
# after 1300 training steps, the loss is 0.782172, the validation accuracy is 0.9326
# after 1400 training steps, the loss is 0.628455, the validation accuracy is 0.9418
# after 1500 training steps, the loss is 0.341639, the validation accuracy is 0.943
# after 1600 training steps, the loss is 0.68244, the validation accuracy is 0.9464
# after 1700 training steps, the loss is 0.426819, the validation accuracy is 0.9432
# after 1800 training steps, the loss is 0.347628, the validation accuracy is 0.944
# after 1900 training steps, the loss is 0.591079, the validation accuracy is 0.9492
# after 2000 training steps, the loss is 0.406129, the validation accuracy is 0.9476
# after 2100 training steps, the loss is 0.600846, the validation accuracy is 0.9498
# after 2200 training steps, the loss is 0.299487, the validation accuracy is 0.9472
# after 2300 training steps, the loss is 0.560645, the validation accuracy is 0.9494
# after 2400 training steps, the loss is 0.313092, the validation accuracy is 0.9532
# after 2500 training steps, the loss is 0.499333, the validation accuracy is 0.9494
# after 2600 training steps, the loss is 0.401293, the validation accuracy is 0.9512
# after 2700 training steps, the loss is 0.347444, the validation accuracy is 0.9518
# after 2800 training steps, the loss is 0.281431, the validation accuracy is 0.9554
# after 2900 training steps, the loss is 0.40091, the validation accuracy is 0.9546
# after 3000 training steps, the loss is 0.301964, the validation accuracy is 0.9566
# after 3100 training steps, the loss is 0.342877, the validation accuracy is 0.958
# after 3200 training steps, the loss is 0.409886, the validation accuracy is 0.9558
# after 3300 training steps, the loss is 0.355671, the validation accuracy is 0.9572
# after 3400 training steps, the loss is 0.239252, the validation accuracy is 0.959
# after 3500 training steps, the loss is 0.227375, the validation accuracy is 0.959
# after 3600 training steps, the loss is 0.505456, the validation accuracy is 0.956
# after 3700 training steps, the loss is 0.335378, the validation accuracy is 0.9578
# after 3800 training steps, the loss is 0.285198, the validation accuracy is 0.958
# after 3900 training steps, the loss is 0.267951, the validation accuracy is 0.956
# after 4000 training steps, the loss is 0.261202, the validation accuracy is 0.96
# after 4100 training steps, the loss is 0.305799, the validation accuracy is 0.9608
# after 4200 training steps, the loss is 0.208313, the validation accuracy is 0.96
# after 4300 training steps, the loss is 0.348377, the validation accuracy is 0.9604
# after 4400 training steps, the loss is 0.48745, the validation accuracy is 0.9636
# after 4500 training steps, the loss is 0.443363, the validation accuracy is 0.9596
# after 4600 training steps, the loss is 0.262371, the validation accuracy is 0.9566
# after 4700 training steps, the loss is 0.556637, the validation accuracy is 0.9624
# after 4800 training steps, the loss is 0.271937, the validation accuracy is 0.9612
# after 4900 training steps, the loss is 0.223637, the validation accuracy is 0.9584
# after 5000 training steps, the loss is 0.265272, the validation accuracy is 0.9646
# after 5100 training steps, the loss is 0.374678, the validation accuracy is 0.9614
# after 5200 training steps, the loss is 0.334291, the validation accuracy is 0.9654
# after 5300 training steps, the loss is 0.193324, the validation accuracy is 0.9644
# after 5400 training steps, the loss is 0.218069, the validation accuracy is 0.9622
# after 5500 training steps, the loss is 0.524348, the validation accuracy is 0.9642
# after 5600 training steps, the loss is 0.453114, the validation accuracy is 0.9656
# after 5700 training steps, the loss is 0.177075, the validation accuracy is 0.9642
# after 5800 training steps, the loss is 0.356655, the validation accuracy is 0.9598
# after 5900 training steps, the loss is 0.317598, the validation accuracy is 0.963
# after 6000 training steps, the loss is 0.325877, the validation accuracy is 0.9596
# after 6100 training steps, the loss is 0.182745, the validation accuracy is 0.9656
# after 6200 training steps, the loss is 0.277489, the validation accuracy is 0.9642
# after 6300 training steps, the loss is 0.329583, the validation accuracy is 0.9654
# after 6400 training steps, the loss is 0.213863, the validation accuracy is 0.9652
# after 6500 training steps, the loss is 0.177806, the validation accuracy is 0.9688
# after 6600 training steps, the loss is 0.266752, the validation accuracy is 0.9662
# after 6700 training steps, the loss is 0.235291, the validation accuracy is 0.964
# after 6800 training steps, the loss is 0.317061, the validation accuracy is 0.964
# after 6900 training steps, the loss is 0.339609, the validation accuracy is 0.9682
# after 7000 training steps, the loss is 0.153029, the validation accuracy is 0.9662
# after 7100 training steps, the loss is 0.191156, the validation accuracy is 0.9656
# after 7200 training steps, the loss is 0.356881, the validation accuracy is 0.9666
# after 7300 training steps, the loss is 0.16551, the validation accuracy is 0.9666
# after 7400 training steps, the loss is 0.221998, the validation accuracy is 0.9672
# after 7500 training steps, the loss is 0.184791, the validation accuracy is 0.9654
# after 7600 training steps, the loss is 0.243367, the validation accuracy is 0.9688
# after 7700 training steps, the loss is 0.353831, the validation accuracy is 0.9696
# after 7800 training steps, the loss is 0.216445, the validation accuracy is 0.9664
# after 7900 training steps, the loss is 0.14108, the validation accuracy is 0.9698
# after 8000 training steps, the loss is 0.162813, the validation accuracy is 0.9704
# after 8100 training steps, the loss is 0.199831, the validation accuracy is 0.971
# after 8200 training steps, the loss is 0.146424, the validation accuracy is 0.9698
# after 8300 training steps, the loss is 0.24055, the validation accuracy is 0.9698
# after 8400 training steps, the loss is 0.166226, the validation accuracy is 0.9694
# after 8500 training steps, the loss is 0.264355, the validation accuracy is 0.9666
# after 8600 training steps, the loss is 0.139598, the validation accuracy is 0.9698
# after 8700 training steps, the loss is 0.200929, the validation accuracy is 0.969
# after 8800 training steps, the loss is 0.143946, the validation accuracy is 0.9712
# after 8900 training steps, the loss is 0.164476, the validation accuracy is 0.9686
# after 9000 training steps, the loss is 0.195578, the validation accuracy is 0.9688
# after 9100 training steps, the loss is 0.136171, the validation accuracy is 0.9686
# after 9200 training steps, the loss is 0.30533, the validation accuracy is 0.9692
# after 9300 training steps, the loss is 0.298148, the validation accuracy is 0.9696
# after 9400 training steps, the loss is 0.28967, the validation accuracy is 0.9704
# after 9500 training steps, the loss is 0.112375, the validation accuracy is 0.9706
# after 9600 training steps, the loss is 0.241071, the validation accuracy is 0.9696
# after 9700 training steps, the loss is 0.175451, the validation accuracy is 0.9692
# after 9800 training steps, the loss is 0.209341, the validation accuracy is 0.9706
# after 9900 training steps, the loss is 0.16186, the validation accuracy is 0.9708
# after 10000 training steps, the loss is 0.147882, the validation accuracy is 0.9702
# after 10100 training steps, the loss is 0.271772, the validation accuracy is 0.9706
# after 10200 training steps, the loss is 0.269033, the validation accuracy is 0.9686
# after 10300 training steps, the loss is 0.19568, the validation accuracy is 0.9696
# after 10400 training steps, the loss is 0.189362, the validation accuracy is 0.9676
# after 10500 training steps, the loss is 0.110334, the validation accuracy is 0.9684
# after 10600 training steps, the loss is 0.173203, the validation accuracy is 0.9702
# after 10700 training steps, the loss is 0.145497, the validation accuracy is 0.9716
# after 10800 training steps, the loss is 0.12446, the validation accuracy is 0.972
# after 10900 training steps, the loss is 0.223523, the validation accuracy is 0.9694
# after 11000 training steps, the loss is 0.205136, the validation accuracy is 0.9694
# after 11100 training steps, the loss is 0.140499, the validation accuracy is 0.9702
# after 11200 training steps, the loss is 0.183402, the validation accuracy is 0.9698
# after 11300 training steps, the loss is 0.12541, the validation accuracy is 0.9716
# after 11400 training steps, the loss is 0.199052, the validation accuracy is 0.9696
# after 11500 training steps, the loss is 0.186238, the validation accuracy is 0.966
# after 11600 training steps, the loss is 0.157586, the validation accuracy is 0.9708
# after 11700 training steps, the loss is 0.136418, the validation accuracy is 0.9714
# after 11800 training steps, the loss is 0.189848, the validation accuracy is 0.9716
# after 11900 training steps, the loss is 0.168193, the validation accuracy is 0.9696
# after 12000 training steps, the loss is 0.23768, the validation accuracy is 0.9702
# after 12100 training steps, the loss is 0.118213, the validation accuracy is 0.9706
# after 12200 training steps, the loss is 0.123459, the validation accuracy is 0.9718
# after 12300 training steps, the loss is 0.316971, the validation accuracy is 0.971
# after 12400 training steps, the loss is 0.122131, the validation accuracy is 0.9704
# after 12500 training steps, the loss is 0.183515, the validation accuracy is 0.9712
# after 12600 training steps, the loss is 0.117644, the validation accuracy is 0.9716
# after 12700 training steps, the loss is 0.125303, the validation accuracy is 0.9718
# after 12800 training steps, the loss is 0.318164, the validation accuracy is 0.9724
# after 12900 training steps, the loss is 0.0949457, the validation accuracy is 0.9682
# after 13000 training steps, the loss is 0.573445, the validation accuracy is 0.9694
# after 13100 training steps, the loss is 0.138804, the validation accuracy is 0.9722
# after 13200 training steps, the loss is 0.106316, the validation accuracy is 0.9694
# after 13300 training steps, the loss is 0.11426, the validation accuracy is 0.9738
# after 13400 training steps, the loss is 0.123363, the validation accuracy is 0.9732
# after 13500 training steps, the loss is 0.191252, the validation accuracy is 0.9716
# after 13600 training steps, the loss is 0.12753, the validation accuracy is 0.9724
# after 13700 training steps, the loss is 0.176471, the validation accuracy is 0.9734
# after 13800 training steps, the loss is 0.0972316, the validation accuracy is 0.9694
# after 13900 training steps, the loss is 0.170752, the validation accuracy is 0.9738
# after 14000 training steps, the loss is 0.187971, the validation accuracy is 0.9716
# after 14100 training steps, the loss is 0.175127, the validation accuracy is 0.9726
# after 14200 training steps, the loss is 0.114234, the validation accuracy is 0.9728
# after 14300 training steps, the loss is 0.0963351, the validation accuracy is 0.9744
# after 14400 training steps, the loss is 0.160464, the validation accuracy is 0.9728
# after 14500 training steps, the loss is 0.170761, the validation accuracy is 0.9734
# after 14600 training steps, the loss is 0.0922291, the validation accuracy is 0.9728
# after 14700 training steps, the loss is 0.191081, the validation accuracy is 0.9712
# after 14800 training steps, the loss is 0.127012, the validation accuracy is 0.971
# after 14900 training steps, the loss is 0.159479, the validation accuracy is 0.972
# after 15000 training steps, the loss is 0.127123, the validation accuracy is 0.9708
# after 15100 training steps, the loss is 0.159754, the validation accuracy is 0.9736
# after 15200 training steps, the loss is 0.315575, the validation accuracy is 0.9702
# after 15300 training steps, the loss is 0.118646, the validation accuracy is 0.9712
# after 15400 training steps, the loss is 0.143038, the validation accuracy is 0.9726
# after 15500 training steps, the loss is 0.177961, the validation accuracy is 0.9726
# after 15600 training steps, the loss is 0.0960307, the validation accuracy is 0.9718
# after 15700 training steps, the loss is 0.22186, the validation accuracy is 0.9718
# after 15800 training steps, the loss is 0.0905328, the validation accuracy is 0.9738
# after 15900 training steps, the loss is 0.13634, the validation accuracy is 0.972
# after 16000 training steps, the loss is 0.340257, the validation accuracy is 0.971
# after 16100 training steps, the loss is 0.192687, the validation accuracy is 0.9738
# after 16200 training steps, the loss is 0.161324, the validation accuracy is 0.9704
# after 16300 training steps, the loss is 0.144848, the validation accuracy is 0.97
# after 16400 training steps, the loss is 0.233882, the validation accuracy is 0.9722
# after 16500 training steps, the loss is 0.195764, the validation accuracy is 0.9736
# after 16600 training steps, the loss is 0.170746, the validation accuracy is 0.973
# after 16700 training steps, the loss is 0.0896815, the validation accuracy is 0.971
# after 16800 training steps, the loss is 0.107887, the validation accuracy is 0.975
# after 16900 training steps, the loss is 0.230628, the validation accuracy is 0.9732
# after 17000 training steps, the loss is 0.153078, the validation accuracy is 0.9748
# after 17100 training steps, the loss is 0.107849, the validation accuracy is 0.971
# after 17200 training steps, the loss is 0.082165, the validation accuracy is 0.9724
# after 17300 training steps, the loss is 0.25939, the validation accuracy is 0.9732
# after 17400 training steps, the loss is 0.078943, the validation accuracy is 0.9738
# after 17500 training steps, the loss is 0.0957567, the validation accuracy is 0.9704
# after 17600 training steps, the loss is 0.0703412, the validation accuracy is 0.9736
# after 17700 training steps, the loss is 0.0901433, the validation accuracy is 0.9736
# after 17800 training steps, the loss is 0.194436, the validation accuracy is 0.9712
# after 17900 training steps, the loss is 0.167388, the validation accuracy is 0.9742
# after 18000 training steps, the loss is 0.118855, the validation accuracy is 0.9724
# after 18100 training steps, the loss is 0.126377, the validation accuracy is 0.9712
# after 18200 training steps, the loss is 0.145458, the validation accuracy is 0.9736
# after 18300 training steps, the loss is 0.110093, the validation accuracy is 0.975
# after 18400 training steps, the loss is 0.180787, the validation accuracy is 0.969
# after 18500 training steps, the loss is 0.156659, the validation accuracy is 0.9746
# after 18600 training steps, the loss is 0.333688, the validation accuracy is 0.9726
# after 18700 training steps, the loss is 0.144019, the validation accuracy is 0.9722
# after 18800 training steps, the loss is 0.174145, the validation accuracy is 0.9738
# after 18900 training steps, the loss is 0.170815, the validation accuracy is 0.9738
# after 19000 training steps, the loss is 0.091103, the validation accuracy is 0.9738
# after 19100 training steps, the loss is 0.16754, the validation accuracy is 0.975
# after 19200 training steps, the loss is 0.143644, the validation accuracy is 0.9728
# after 19300 training steps, the loss is 0.136154, the validation accuracy is 0.9734
# after 19400 training steps, the loss is 0.0936904, the validation accuracy is 0.9724
# after 19500 training steps, the loss is 0.173954, the validation accuracy is 0.9706
# after 19600 training steps, the loss is 0.173436, the validation accuracy is 0.9726
# after 19700 training steps, the loss is 0.118075, the validation accuracy is 0.9744
# after 19800 training steps, the loss is 0.137384, the validation accuracy is 0.9742
# after 19900 training steps, the loss is 0.211558, the validation accuracy is 0.9728
# the traning is finish!
# the train accuracy is : 0.9829091
# the test accuracy is : 0.9686

# %% [markdown]
# ## 使模型变得复杂后，发现效果反而不好，准确率不高并且耗时很长，准确率也只有96%

# %% [markdown]
# ## 经过上面多种尝试，发现只是增加了迭代次数、增加了神经元数量以及调整了学习率，
#
# ## 效果就能达到比较好的效果。结合这个，最终训练的最优模型如下

# %%
train(batch_size=32, training_step=20000, lr=0.1,hidden1=1000, hidden2=1000)
# Out:
# after 100 training steps, the loss is 0.237222, the validation accuracy is 0.9012
# after 200 training steps, the loss is 0.385639, the validation accuracy is 0.9278
# after 300 training steps, the loss is 0.0987822, the validation accuracy is 0.9336
# after 400 training steps, the loss is 0.101503, the validation accuracy is 0.9508
# after 500 training steps, the loss is 0.118876, the validation accuracy is 0.9452
# after 600 training steps, the loss is 0.108847, the validation accuracy is 0.951
# after 700 training steps, the loss is 0.315249, the validation accuracy is 0.9522
# after 800 training steps, the loss is 0.0699681, the validation accuracy is 0.9578
# after 900 training steps, the loss is 0.146829, the validation accuracy is 0.957
# after 1000 training steps, the loss is 0.104086, the validation accuracy is 0.9632
# after 1100 training steps, the loss is 0.189242, the validation accuracy is 0.9602
# after 1200 training steps, the loss is 0.0288254, the validation accuracy is 0.9654
# after 1300 training steps, the loss is 0.0177853, the validation accuracy is 0.9666
# after 1400 training steps, the loss is 0.0284373, the validation accuracy is 0.9598
# after 1500 training steps, the loss is 0.0631954, the validation accuracy is 0.9688
# after 1600 training steps, the loss is 0.197017, the validation accuracy is 0.9692
# after 1700 training steps, the loss is 0.0460275, the validation accuracy is 0.9694
# after 1800 training steps, the loss is 0.156827, the validation accuracy is 0.969
# after 1900 training steps, the loss is 0.0152905, the validation accuracy is 0.9704
# after 2000 training steps, the loss is 0.0626582, the validation accuracy is 0.9676
# after 2100 training steps, the loss is 0.0699792, the validation accuracy is 0.9722
# after 2200 training steps, the loss is 0.0148685, the validation accuracy is 0.97
# after 2300 training steps, the loss is 0.05232, the validation accuracy is 0.9718
# after 2400 training steps, the loss is 0.124114, the validation accuracy is 0.9672
# after 2500 training steps, the loss is 0.0127214, the validation accuracy is 0.9738
# after 2600 training steps, the loss is 0.0364746, the validation accuracy is 0.9746
# after 2700 training steps, the loss is 0.236376, the validation accuracy is 0.9742
# after 2800 training steps, the loss is 0.040679, the validation accuracy is 0.9666
# after 2900 training steps, the loss is 0.0181409, the validation accuracy is 0.9774
# after 3000 training steps, the loss is 0.028474, the validation accuracy is 0.9758
# after 3100 training steps, the loss is 0.0217383, the validation accuracy is 0.9758
# after 3200 training steps, the loss is 0.180935, the validation accuracy is 0.9724
# after 3300 training steps, the loss is 0.035008, the validation accuracy is 0.9766
# after 3400 training steps, the loss is 0.0377508, the validation accuracy is 0.9756
# after 3500 training steps, the loss is 0.0242123, the validation accuracy is 0.9754
# after 3600 training steps, the loss is 0.0126806, the validation accuracy is 0.979
# after 3700 training steps, the loss is 0.00866514, the validation accuracy is 0.9766
# after 3800 training steps, the loss is 0.00851632, the validation accuracy is 0.9782
# after 3900 training steps, the loss is 0.0252006, the validation accuracy is 0.9776
# after 4000 training steps, the loss is 0.0303221, the validation accuracy is 0.979
# after 4100 training steps, the loss is 0.00305433, the validation accuracy is 0.9778
# after 4200 training steps, the loss is 0.0389563, the validation accuracy is 0.98
# after 4300 training steps, the loss is 0.0332114, the validation accuracy is 0.9778
# after 4400 training steps, the loss is 0.121025, the validation accuracy is 0.9736
# after 4500 training steps, the loss is 0.00638908, the validation accuracy is 0.9768
# after 4600 training steps, the loss is 0.015972, the validation accuracy is 0.9748
# after 4700 training steps, the loss is 0.0318709, the validation accuracy is 0.9792
# after 4800 training steps, the loss is 0.00259631, the validation accuracy is 0.9798
# after 4900 training steps, the loss is 0.00941174, the validation accuracy is 0.9788
# after 5000 training steps, the loss is 0.00437877, the validation accuracy is 0.9798
# after 5100 training steps, the loss is 0.00762622, the validation accuracy is 0.98
# after 5200 training steps, the loss is 0.0415779, the validation accuracy is 0.9792
# after 5300 training steps, the loss is 0.00918246, the validation accuracy is 0.9796
# after 5400 training steps, the loss is 0.00402424, the validation accuracy is 0.9788
# after 5500 training steps, the loss is 0.0100731, the validation accuracy is 0.9794
# after 5600 training steps, the loss is 0.017663, the validation accuracy is 0.98
# after 5700 training steps, the loss is 0.00442769, the validation accuracy is 0.978
# after 5800 training steps, the loss is 0.00142857, the validation accuracy is 0.9792
# after 5900 training steps, the loss is 0.00363933, the validation accuracy is 0.9788
# after 6000 training steps, the loss is 0.0402844, the validation accuracy is 0.98
# after 6100 training steps, the loss is 0.0188984, the validation accuracy is 0.979
# after 6200 training steps, the loss is 0.0443254, the validation accuracy is 0.9806
# after 6300 training steps, the loss is 0.0408359, the validation accuracy is 0.9788
# after 6400 training steps, the loss is 0.0357327, the validation accuracy is 0.9786
# after 6500 training steps, the loss is 0.0466605, the validation accuracy is 0.9822
# after 6600 training steps, the loss is 0.0152468, the validation accuracy is 0.9788
# after 6700 training steps, the loss is 0.00718572, the validation accuracy is 0.9774
# after 6800 training steps, the loss is 0.014794, the validation accuracy is 0.9802
# after 6900 training steps, the loss is 0.0475996, the validation accuracy is 0.9794
# after 7000 training steps, the loss is 0.02887, the validation accuracy is 0.9806
# after 7100 training steps, the loss is 0.00255236, the validation accuracy is 0.9822
# after 7200 training steps, the loss is 0.00913419, the validation accuracy is 0.9808
# after 7300 training steps, the loss is 0.00212888, the validation accuracy is 0.9794
# after 7400 training steps, the loss is 0.00571043, the validation accuracy is 0.9806
# after 7500 training steps, the loss is 0.0020713, the validation accuracy is 0.9814
# after 7600 training steps, the loss is 0.00260407, the validation accuracy is 0.9812
# after 7700 training steps, the loss is 0.095168, the validation accuracy is 0.982
# after 7800 training steps, the loss is 0.00162172, the validation accuracy is 0.9806
# after 7900 training steps, the loss is 0.00500225, the validation accuracy is 0.9798
# after 8000 training steps, the loss is 0.0059375, the validation accuracy is 0.9818
# after 8100 training steps, the loss is 0.0110142, the validation accuracy is 0.9808
# after 8200 training steps, the loss is 0.00770714, the validation accuracy is 0.9814
# after 8300 training steps, the loss is 0.0139711, the validation accuracy is 0.9818
# after 8400 training steps, the loss is 0.00455656, the validation accuracy is 0.9814
# after 8500 training steps, the loss is 0.00699838, the validation accuracy is 0.9828
# after 8600 training steps, the loss is 0.0111141, the validation accuracy is 0.9818
# after 8700 training steps, the loss is 0.0116173, the validation accuracy is 0.9818
# after 8800 training steps, the loss is 0.000164126, the validation accuracy is 0.9826
# after 8900 training steps, the loss is 0.00285747, the validation accuracy is 0.9828
# after 9000 training steps, the loss is 0.00239287, the validation accuracy is 0.9834
# after 9100 training steps, the loss is 0.00674219, the validation accuracy is 0.9822
# after 9200 training steps, the loss is 0.000886994, the validation accuracy is 0.983
# after 9300 training steps, the loss is 0.00648435, the validation accuracy is 0.9828
# after 9400 training steps, the loss is 0.000935301, the validation accuracy is 0.9834
# after 9500 training steps, the loss is 0.00114665, the validation accuracy is 0.9828
# after 9600 training steps, the loss is 0.00287384, the validation accuracy is 0.9824
# after 9700 training steps, the loss is 0.00108461, the validation accuracy is 0.9826
# after 9800 training steps, the loss is 0.0050487, the validation accuracy is 0.9816
# after 9900 training steps, the loss is 0.00112749, the validation accuracy is 0.9826
# after 10000 training steps, the loss is 0.00191448, the validation accuracy is 0.982
# after 10100 training steps, the loss is 0.00147388, the validation accuracy is 0.9826
# after 10200 training steps, the loss is 0.00134426, the validation accuracy is 0.983
# after 10300 training steps, the loss is 0.00171471, the validation accuracy is 0.9826
# after 10400 training steps, the loss is 0.00302469, the validation accuracy is 0.9826
# after 10500 training steps, the loss is 0.00163191, the validation accuracy is 0.9836
# after 10600 training steps, the loss is 0.0109626, the validation accuracy is 0.9824
# after 10700 training steps, the loss is 0.00312855, the validation accuracy is 0.9832
# after 10800 training steps, the loss is 0.00252614, the validation accuracy is 0.9828
# after 10900 training steps, the loss is 0.000801301, the validation accuracy is 0.9834
# after 11000 training steps, the loss is 0.00166564, the validation accuracy is 0.9816
# after 11100 training steps, the loss is 0.00267436, the validation accuracy is 0.9838
# after 11200 training steps, the loss is 0.00482678, the validation accuracy is 0.9834
# after 11300 training steps, the loss is 0.000828761, the validation accuracy is 0.984
# after 11400 training steps, the loss is 0.000573555, the validation accuracy is 0.9834
# after 11500 training steps, the loss is 0.00178174, the validation accuracy is 0.983
# after 11600 training steps, the loss is 0.000393342, the validation accuracy is 0.9836
# after 11700 training steps, the loss is 0.000583333, the validation accuracy is 0.9828
# after 11800 training steps, the loss is 0.00278155, the validation accuracy is 0.9832
# after 11900 training steps, the loss is 0.000839324, the validation accuracy is 0.9838
# after 12000 training steps, the loss is 0.000574564, the validation accuracy is 0.9834
# after 12100 training steps, the loss is 0.00342902, the validation accuracy is 0.983
# after 12200 training steps, the loss is 0.00122311, the validation accuracy is 0.9838
# after 12300 training steps, the loss is 0.0010093, the validation accuracy is 0.9832
# after 12400 training steps, the loss is 0.00252498, the validation accuracy is 0.9832
# after 12500 training steps, the loss is 0.000932604, the validation accuracy is 0.9838
# after 12600 training steps, the loss is 0.000723564, the validation accuracy is 0.9844
# after 12700 training steps, the loss is 0.000540222, the validation accuracy is 0.984
# after 12800 training steps, the loss is 0.00018066, the validation accuracy is 0.9832
# after 12900 training steps, the loss is 0.00119726, the validation accuracy is 0.9836
# after 13000 training steps, the loss is 0.000450698, the validation accuracy is 0.983
# after 13100 training steps, the loss is 0.00122086, the validation accuracy is 0.983
# after 13200 training steps, the loss is 0.00176708, the validation accuracy is 0.984
# after 13300 training steps, the loss is 0.000165049, the validation accuracy is 0.9838
# after 13400 training steps, the loss is 0.00326886, the validation accuracy is 0.983
# after 13500 training steps, the loss is 0.00502431, the validation accuracy is 0.9824
# after 13600 training steps, the loss is 0.001294, the validation accuracy is 0.9826
# after 13700 training steps, the loss is 0.000343135, the validation accuracy is 0.9826
# after 13800 training steps, the loss is 0.00164167, the validation accuracy is 0.9832
# after 13900 training steps, the loss is 0.00125318, the validation accuracy is 0.983
# after 14000 training steps, the loss is 0.00105255, the validation accuracy is 0.9836
# after 14100 training steps, the loss is 0.000659447, the validation accuracy is 0.9834
# after 14200 training steps, the loss is 0.000647939, the validation accuracy is 0.9836
# after 14300 training steps, the loss is 0.00184615, the validation accuracy is 0.9834
# after 14400 training steps, the loss is 0.00165798, the validation accuracy is 0.9838
# after 14500 training steps, the loss is 0.00157912, the validation accuracy is 0.983
# after 14600 training steps, the loss is 0.000529204, the validation accuracy is 0.984
# after 14700 training steps, the loss is 0.00322392, the validation accuracy is 0.9832
# after 14800 training steps, the loss is 0.00146265, the validation accuracy is 0.9838
# after 14900 training steps, the loss is 0.00104528, the validation accuracy is 0.9834
# after 15000 training steps, the loss is 3.28685e-05, the validation accuracy is 0.983
# after 15100 training steps, the loss is 0.00158826, the validation accuracy is 0.9834
# after 15200 training steps, the loss is 0.000359481, the validation accuracy is 0.983
# after 15300 training steps, the loss is 0.00304415, the validation accuracy is 0.983
# after 15400 training steps, the loss is 0.00157975, the validation accuracy is 0.9838
# after 15500 training steps, the loss is 0.000595275, the validation accuracy is 0.9836
# after 15600 training steps, the loss is 0.00140816, the validation accuracy is 0.9836
# after 15700 training steps, the loss is 0.000370741, the validation accuracy is 0.9844
# after 15800 training steps, the loss is 0.00103828, the validation accuracy is 0.9834
# after 15900 training steps, the loss is 0.00139463, the validation accuracy is 0.9832
# after 16000 training steps, the loss is 0.000988924, the validation accuracy is 0.9826
# after 16100 training steps, the loss is 0.00343861, the validation accuracy is 0.9832
# after 16200 training steps, the loss is 0.000412703, the validation accuracy is 0.9832
# after 16300 training steps, the loss is 0.00238824, the validation accuracy is 0.9834
# after 16400 training steps, the loss is 2.53242e-05, the validation accuracy is 0.983
# after 16500 training steps, the loss is 0.00174211, the validation accuracy is 0.984
# after 16600 training steps, the loss is 0.000855574, the validation accuracy is 0.983
# after 16700 training steps, the loss is 0.000425494, the validation accuracy is 0.983
# after 16800 training steps, the loss is 0.00173958, the validation accuracy is 0.9838
# after 16900 training steps, the loss is 0.00132729, the validation accuracy is 0.984
# after 17000 training steps, the loss is 9.93451e-05, the validation accuracy is 0.984
# after 17100 training steps, the loss is 0.000966682, the validation accuracy is 0.9838
# after 17200 training steps, the loss is 0.000665259, the validation accuracy is 0.9842
# after 17300 training steps, the loss is 0.000367599, the validation accuracy is 0.9834
# after 17400 training steps, the loss is 0.00163564, the validation accuracy is 0.9834
# after 17500 training steps, the loss is 0.00323498, the validation accuracy is 0.983
# after 17600 training steps, the loss is 0.000931768, the validation accuracy is 0.9836
# after 17700 training steps, the loss is 0.000539721, the validation accuracy is 0.9834
# after 17800 training steps, the loss is 0.000353755, the validation accuracy is 0.9832
# after 17900 training steps, the loss is 8.37376e-05, the validation accuracy is 0.9834
# after 18000 training steps, the loss is 0.000384829, the validation accuracy is 0.9832
# after 18100 training steps, the loss is 0.00143035, the validation accuracy is 0.983
# after 18200 training steps, the loss is 0.00104816, the validation accuracy is 0.9834
# after 18300 training steps, the loss is 0.000976495, the validation accuracy is 0.9828
# after 18400 training steps, the loss is 0.000243043, the validation accuracy is 0.983
# after 18500 training steps, the loss is 0.000198576, the validation accuracy is 0.9832
# after 18600 training steps, the loss is 0.000637519, the validation accuracy is 0.9842
# after 18700 training steps, the loss is 0.000234476, the validation accuracy is 0.9832
# after 18800 training steps, the loss is 0.00013246, the validation accuracy is 0.9834
# after 18900 training steps, the loss is 4.8829e-05, the validation accuracy is 0.984
# after 19000 training steps, the loss is 0.00045884, the validation accuracy is 0.9842
# after 19100 training steps, the loss is 0.00194665, the validation accuracy is 0.9836
# after 19200 training steps, the loss is 0.000854849, the validation accuracy is 0.9838
# after 19300 training steps, the loss is 0.0016187, the validation accuracy is 0.9836
# after 19400 training steps, the loss is 0.00148027, the validation accuracy is 0.984
# after 19500 training steps, the loss is 0.00122844, the validation accuracy is 0.9836
# after 19600 training steps, the loss is 0.00188233, the validation accuracy is 0.9834
# after 19700 training steps, the loss is 0.000235774, the validation accuracy is 0.9834
# after 19800 training steps, the loss is 0.000775239, the validation accuracy is 0.9834
# after 19900 training steps, the loss is 0.00463729, the validation accuracy is 0.9842
# the traning is finish!
# the train accuracy is : 1.0
# the test accuracy is : 0.9828

# %% [markdown]
# 总结：
# 经过上面的训练，发现，调整训练次数，增加神经元个数能够达到较好的提升训练性能。但是如果过于复杂，性能却反而不好。
#
# 本次训练最终取得的测试集准确率约为98.2%，参数为训练次数20000步，学习率0.1，双隐层结构，每个隐层神经元个数为1000个，batch_size=32。
#
# 通过上面对于正则项的添加可以看出，单纯对比的话，L2效果要好于L1正则。但是正则的作用是缩小训练集和测试集的距离，对模型最终效果提升并不是很大。
